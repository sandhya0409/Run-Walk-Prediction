# %% [markdown]
# # Task 1:-Prepare a complete data analysis report on the given data.

# %%
import numpy as np #'Numpy' is used for mathematical operations on large, multi-dimensional arrays and matrices

import pandas as pd #'Pandas' is used for data manipulation and analysis

# %%
#importing dataset
df=pd.read_csv("walkrun.csv")

# %%
#df.head()-->empty argument-->gives 5 rows-->ordered
#df.tail()-->empty argument-->gives 5 rows-->ordered(from downards)
#df.sample()-->empty argument-->gives 1 row-->unordered

# %%
df.count()
# Out:
# date              88588
# time              88588
# username          88588
# wrist             88588
# activity          88588
# acceleration_x    88588
# acceleration_y    88588
# acceleration_z    88588
# gyro_x            88588
# gyro_y            88588
# gyro_z            88588
# dtype: int64

# %% [markdown]
# # summary statistics
# # if the DataFrame contains numerical data, the description contains these information for each column:
#
# - count - The number of not-empty values.
# - mean - The average (mean) value.
# - std - The standard deviation.
# - min - the minimum value.
# - 25% - The 25% percentile*.
# - 50% - The 50% percentile*.
# - 75% - The 75% percentile*.
# - max - the maximum value.

# %%
df.describe().transpose()
# Out:
#                   count      mean       std     min       25%     50%  \
# wrist           88588.0  0.522170  0.499511  0.0000  0.000000  1.0000
# activity        88588.0  0.500801  0.500002  0.0000  0.000000  1.0000
# acceleration_x  88588.0 -0.074811  1.009299 -5.3505 -0.381800 -0.0595
# acceleration_y  88588.0 -0.562585  0.658458 -3.2990 -1.033500 -0.7591
# acceleration_z  88588.0 -0.313956  0.486815 -3.7538 -0.376000 -0.2210
# gyro_x          88588.0  0.004160  1.253423 -4.4306 -0.920700  0.0187
# gyro_y          88588.0  0.037203  1.198725 -7.4647 -0.644825  0.0393
# gyro_z          88588.0  0.022327  1.914423 -9.4800 -1.345125  0.0069
#
#                      75%      max
# wrist           1.000000   1.0000
# activity        1.000000   1.0000
# acceleration_x  0.355500   5.6033
# acceleration_y -0.241775   2.6680
# acceleration_z -0.085900   1.6403
# gyro_x          0.888800   4.8742
# gyro_y          0.733700   8.4980
# gyro_z          1.398200  11.2662

# %%
#Checking Datatypes.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            88588 non-null  object
#  1   time            88588 non-null  object
#  2   username        88588 non-null  object
#  3   wrist           88588 non-null  int64
#  4   activity        88588 non-null  int64
#  5   acceleration_x  88588 non-null  float64
#  6   acceleration_y  88588 non-null  float64
#  7   acceleration_z  88588 non-null  float64
#  8   gyro_x          88588 non-null  float64
#  9   gyro_y          88588 non-null  float64
#  10  gyro_z          88588 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 7.4+ MB

# %%
#Dimensions of data
df.shape
# Out:
# (88588, 11)

# %%
#checking missing values in the dataset.
df.isnull().sum()
#no features has missing values.
# Out:
# date              0
# time              0
# username          0
# wrist             0
# activity          0
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# dtype: int64

# %%
#checking for duplicates.
df.duplicated().sum()
# Out:
# 0

# %%
#Recheck for unique value
for column in df.columns:
    if df[column].dtype == 'object':
        print(column.upper(),':',df[column].nunique())
        print(df[column].value_counts().sort_values())
        print('\n')
# Out:
# DATE : 12
# date
# 2017-7-4      3225
# 2017-7-7      3280
# 2017-7-2      3933
# 2017-6-30     3992
# 2017-7-1      4201
# 2017-7-10     4337
# 2017-7-11     6696
# 2017-7-9      7788
# 2017-7-15     7934
# 2017-7-6     11357
# 2017-7-17    11365
# 2017-7-16    20480
# Name: count, dtype: int64
#
#
# TIME : 88588
# time
# 13:51:15:847724020    1
# 13:51:17:246767997    1
# 13:51:17:446569025    1
# 13:51:17:646152973    1
# 13:51:17:846502006    1
#                      ..
# 20:9:12:517301976     1
# 20:9:12:317988991     1
# 20:9:12:117035984     1
# 20:9:14:917038023     1
# 20:9:16:117410004     1
# Name: count, Length: 88588, dtype: int64
#
#
# USERNAME : 1
# username
# viktor    88588
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (88588, 11)

# %%
df
# Out:
#             date                time username  wrist  activity  \
# 0      2017-6-30  13:51:15:847724020   viktor      0         0
# 1      2017-6-30  13:51:16:246945023   viktor      0         0
# 2      2017-6-30  13:51:16:446233987   viktor      0         0
# 3      2017-6-30  13:51:16:646117985   viktor      0         0
# 4      2017-6-30  13:51:16:846738994   viktor      0         0
# ...          ...                 ...      ...    ...       ...
# 88583   2017-7-9   20:9:15:317911028   viktor      0         0
# 88584   2017-7-9   20:9:15:517889022   viktor      0         0
# 88585   2017-7-9   20:9:15:717828989   viktor      0         0
# 88586   2017-7-9   20:9:15:917932987   viktor      0         0
# 88587   2017-7-9   20:9:16:117410004   viktor      0         0
#
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# ...

# %%
df.drop(['date','time','username'], axis=1,inplace= True)

# %%
df.head()
# Out:
#    wrist  activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  \
# 0      0         0          0.2650         -0.7814         -0.0076 -0.0590
# 1      0         0          0.6722         -1.1233         -0.2344 -0.1757
# 2      0         0          0.4399         -1.4817          0.0722 -0.9105
# 3      0         0          0.3031         -0.8125          0.0888  0.1199
# 4      0         0          0.4814         -0.9312          0.0359  0.0527
#
#    gyro_y  gyro_z
# 0  0.0325 -2.9296
# 1  0.0208  0.1269
# 2  0.1063 -2.4367
# 3 -0.4099 -2.9336
# 4  0.4379  2.4922

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
#analysis of outliers
plt.figure(figsize=(18,18))
i=1
for x in df.columns:
    plt.subplot(4,4,i)
    sns.boxplot(y=df[x])
    plt.title(x)
    i+=1

# %%
#classifying activities into walk and run
#0:"walk"
#1:"run"

# %%
print('df contains ' + str(pd.value_counts(df['activity'].values)[0]) +
      ' "walk" data samples as well as ' + str(pd.value_counts(df['activity'].values)[1]) + 
      ' "run" data samples')
# Out:
# df contains 44223 "walk" data samples as well as 44365 "run" data samples
# C:\Users\sandh\AppData\Local\Temp\ipykernel_20304\3999365365.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print('df contains ' + str(pd.value_counts(df['activity'].values)[0]) +
# C:\Users\sandh\AppData\Local\Temp\ipykernel_20304\3999365365.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   ' "walk" data samples as well as ' + str(pd.value_counts(df['activity'].values)[1]) +

# %%
#Classifying wrist into left and right:
#0:"left"
#1:"right"

# %%
print('The data contains ' + str(pd.value_counts(df['wrist'].values)[0]) + 
      ' data samples collected on the left wrist as well as ' + str(pd.value_counts(df['wrist'].values)[1]) + 
      ' data samples collected on the right wrist')
# Out:
# The data contains 42330 data samples collected on the left wrist as well as 46258 data samples collected on the right wrist
# C:\Users\sandh\AppData\Local\Temp\ipykernel_20304\2203560376.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print('The data contains ' + str(pd.value_counts(df['wrist'].values)[0]) +
# C:\Users\sandh\AppData\Local\Temp\ipykernel_20304\2203560376.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   ' data samples collected on the left wrist as well as ' + str(pd.value_counts(df['wrist'].values)[1]) +

# %%
df.copy = df.copy()

# %%
Features = ['acceleration_x','acceleration_y','acceleration_z','gyro_x','gyro_y','gyro_z']
# populate dataframe with 'left' wrist only
df_left_wrist_data = pd.DataFrame()
df_left_wrist_data = df.copy[df.copy.wrist == 0]

# populate dataframe with 'right' wrist only
df_right_wrist_data = pd.DataFrame()
df_right_wrist_data = df.copy[df.copy.wrist == 1]

# %%
# Set figure size and adjust bin width
plt.figure(figsize=(8, 4))
bin_width = 0.2  # Adjust as needed
for c in Features:
    plt.title("Data distribution for both wrists")
    sns.histplot(df_left_wrist_data[c], bins=int((df_left_wrist_data[c].max() - df_left_wrist_data[c].min()) / bin_width), label='left',color='green')
    sns.histplot(df_right_wrist_data[c], bins=int((df_right_wrist_data[c].max() - df_right_wrist_data[c].min()) / bin_width), label='right', color='blue')
    plt.xlabel(c)
    plt.legend()
    plt.show()
# Out:
# C:\Users\sandh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sandh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sandh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Correlation plot
plt.figure(figsize=(20,18))
sns.heatmap(df.corr(), cmap='YlGnBu',annot=True)
plt.show()

# %%
sns.pairplot(df,diag_kind='knd')

# %% [markdown]
# # Skewness is a statistical measure that helps to understand the symmetry of the distribution of
# # a dataset.
# # It indicates whether the data is skewed to the left or right or if it's symmetric.
# # Skewness can be calculated using various statistical methods,
# # but one common approach is to use the third standardized moment.

# %%
#Checking skewness of the dataset.
plt.figure(figsize=(18,18))
i = 1
for x in df.columns:
    plt.subplot(4,4,i)
    sns.distplot(df[x])
    plt.title(x)
    i+=1
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_20304\3380835173.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x])
# C:\Users\sandh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sandh\AppData\Local\Temp\ipykernel_20304\3380835173.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Model creation 
df.head()
# Out:
#    wrist  activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  \
# 0      0         0          0.2650         -0.7814         -0.0076 -0.0590
# 1      0         0          0.6722         -1.1233         -0.2344 -0.1757
# 2      0         0          0.4399         -1.4817          0.0722 -0.9105
# 3      0         0          0.3031         -0.8125          0.0888  0.1199
# 4      0         0          0.4814         -0.9312          0.0359  0.0527
#
#    gyro_y  gyro_z
# 0  0.0325 -2.9296
# 1  0.0208  0.1269
# 2  0.1063 -2.4367
# 3 -0.4099 -2.9336
# 4  0.4379  2.4922

# %%
x = df.drop(['wrist','activity'],axis=1)
y = df[['activity']]

# %%
x
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1              0.6722         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2              0.4399         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3              0.3031         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4              0.4814         -0.9312          0.0359  0.0527  0.4379  2.4922
# ...               ...             ...             ...     ...     ...     ...
# 88583          0.3084         -0.8376         -0.1327  0.4823  2.0124  0.6048
# 88584          0.4977         -1.0027         -0.4397  0.1022 -1.2565 -0.0761
# 88585          0.4587         -1.1780         -0.2827 -1.4500 -0.2792 -1.2616
# 88586          0.2590         -0.8582         -0.0759 -1.5165  0.4560 -1.7755
# 88587          0.3140         -0.8008         -0.0911  0.1183  1.0850  1.2814
#
# [88588 rows x 6 columns]

# %%
#Feature scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)
x_scaled
# Out:
# array([[ 0.33668266, -0.33231618,  0.6293112 , -0.05039065, -0.00392358,
#         -1.5419494 ],
#        [ 0.74013342, -0.85156246,  0.16342314, -0.14349622, -0.013684  ,
#          0.05462392],
#        [ 0.50997229, -1.39586742,  0.79323478, -0.72973418,  0.05764218,
#         -1.28448139],
#        ...,
#        [ 0.52859919, -0.93463579,  0.06420624, -1.16015794, -0.26395131,
#         -0.67066385],
#        [ 0.3307379 , -0.44895295,  0.4890107 , -1.21321296,  0.34937044,
#         -0.93910129],
#        [ 0.3852315 , -0.36177911,  0.45778716,  0.09106279,  0.87409756,
#          0.65768097]])

# %%
#train- test split 
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.20,random_state=100)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((70870, 6), (17718, 6), (70870, 1), (17718, 1))

# %%
#Linear Regression model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
Y_Pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print(confusion_matrix(y_test,Y_Pred))
print(classification_report(y_test,Y_Pred))
lr_ac = accuracy_score(y_test,Y_Pred)
print(lr_ac)
# Out:
# [[8020  878]
#  [1683 7137]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      8898
#            1       0.89      0.81      0.85      8820
#
#     accuracy                           0.86     17718
#    macro avg       0.86      0.86      0.86     17718
# weighted avg       0.86      0.86      0.86     17718
#
# 0.8554577266057117

# %%
#Decision Tree 
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(splitter='best',criterion='entropy',min_samples_leaf=3,min_samples_split=3)
dt.fit(X_train,y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(confusion_matrix(y_test,Y_pred_dt))
print(classification_report(y_test,Y_pred_dt))
dt_ac = accuracy_score(y_test,Y_pred_dt)
print(dt_ac)
# Out:
# [[8767  131]
#  [ 140 8680]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      8898
#            1       0.99      0.98      0.98      8820
#
#     accuracy                           0.98     17718
#    macro avg       0.98      0.98      0.98     17718
# weighted avg       0.98      0.98      0.98     17718
#
# 0.9847048199571058

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 200,min_samples_split = 2,min_samples_leaf = 1,max_features ='sqrt',criterion='entropy')
rf.fit(X_train,y_train)
Y_pred_rf = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,Y_pred_rf))
print(classification_report(y_test,Y_pred_rf))
rf_ac = accuracy_score(y_test,Y_pred_rf)
print(rf_ac)
# Out:
# [[8828   70]
#  [ 100 8720]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      8898
#            1       0.99      0.99      0.99      8820
#
#     accuracy                           0.99     17718
#    macro avg       0.99      0.99      0.99     17718
# weighted avg       0.99      0.99      0.99     17718
#
# 0.9904052376114686

# %%
#XGredientBoosting
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state = 42,verbosity = 0,silent = 0)
xgb.fit(X_train,y_train)
Y_Pred_xgb = (xgb.predict(X_test))

# %%
print(confusion_matrix(y_test,Y_Pred_xgb))
print(classification_report(y_test,Y_Pred_xgb))
xgb_ac = accuracy_score(y_test,Y_Pred_xgb)
print(xgb_ac)
# Out:
# [[8839   59]
#  [ 106 8714]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      8898
#            1       0.99      0.99      0.99      8820
#
#     accuracy                           0.99     17718
#    macro avg       0.99      0.99      0.99     17718
# weighted avg       0.99      0.99      0.99     17718
#
# 0.9906874365052489

# %%
#Model Perfomance:
#Accuracy score comparison chart

# %%
Accuracy_Score_1 = pd.DataFrame([lr_ac,dt_ac,rf_ac,xgb_ac],index = ['Logistic Regression','Decision Tree','Random Forest','XGradient Boosting'],columns = ['Accuracy'])

# %%
Accuracy_Score_1
# Out:
#                      Accuracy
# Logistic Regression  0.855458
# Decision Tree        0.984705
# Random Forest        0.990405
# XGradient Boosting   0.990687

# %%
Accuracy_Score = [lr_ac,dt_ac,rf_ac,xgb_ac]
Models = ['Logistic Regression','Decision Tree','Random Forest BR','XGradient Boosting']

# %%
sns.barplot(x = Accuracy_Score,y = Models,color = "green")
plt.xlabel('Accuracy_Score')
plt.title('Accuracy_Score')
plt.show()
